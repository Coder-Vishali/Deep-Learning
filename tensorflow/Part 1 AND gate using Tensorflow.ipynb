# %% [markdown]
# # Implementation of AND gate using Tensorflow.

# %% [markdown]
# This exercise implements the AND Gate using tensorflow, by specifying the hidden layers, cost function and Gradient descent optimization. It performs forward propagation.
#
# Modify this program to implement backward propagation.

# %%
# Importing packages.
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#Creating dataset

AND_X = [[0,0],[0,1],[1,0],[1,1]]
AND_Y = [[0],[0],[0],[1]]

# %%
# Creating placeholders for datasets.

x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

# %%
# Creating weights and biases

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

# %%
# Adding hidden layers

# hidden layer 1
with tf.name_scope("layer2") as scope:
    A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

# hidden layer 2
with tf.name_scope("layer3") as scope:
    Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

# %%
# Defining cost function = log loss

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

# %%
# Defining training operation.

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)# learning rate = 0.01

# %%
# Initilising variables and session.

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
# Training the model - Forward Propagation

t_start = time.clock()
for i in range(10000):
    sess.run(train_step, feed_dict={x_: AND_X, y_: AND_Y})
    if i % 1000 == 0:
        print('Epoch ', i)
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: AND_X, y_: AND_Y}))
        print('Theta1 ', sess.run(Theta1))
        print('Bias1 ', sess.run(Bias1))
        print('Theta2 ', sess.run(Theta2))
        print('Bias2 ', sess.run(Bias2))
        print('cost ', sess.run(cost, feed_dict={x_: AND_X, y_: AND_Y}))
t_end = time.clock()

print('Elapsed time ', t_end - t_start)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch  0
# Hypothesis  [[0.4685481 ]
#  [0.461449  ]
#  [0.46227863]
#  [0.4542591 ]]
# Theta1  [[-0.28854686 -0.8656875 ]
#  [ 0.58461785  0.6749029 ]]
# Bias1  [ 0.00029091 -0.00014844]
# Theta2  [[-0.572379  ]
#  [ 0.32478726]]
# Bias2  [-0.0021244]
# cost  0.6651295
# Epoch  1000
# Hypothesis  [[0.25864536]
#  [0.24361241]
#  [0.2782473 ]
#  [0.2622971 ]]
# Theta1  [[-0.47036654 -0.84641606]
#  [ 0.3818156   0.6937808 ]]
# Bias1  [ 0.09742174 -0.02003932]
# Theta2  [[-0.84594053]
#  [-0.00648867]]
# Bias2  [-0.60625213]
# cost  0.5607069
# Epoch  2000
# Hypothesis  [[0.23536804]
#  [0.22910833]
#  [0.2699511 ]
#  [0.26353204]]
# Theta1  [[-0.7313849  -0.8582033 ]
#  [ 0.10515514  0.68160594]]
# Bias1  [ 0.10094304 -0.02129929]
# Theta2  [[-0.96287304]
#  [-0.06043165]]
# Bias2  [-0.6426352]
# cost  0.54419804
# Epoch  3000
# Hypothesis  [[0.21473983]
#  [0.22059447]
#  [0.26971948]
#  [0.2748562 ]]
# Theta1  [[-0.99332076 -0.88208014]
#  [-0.16383411  0.6567912 ]]
# Bias1  [ 0.13856988 -0.02475473]
# Theta2  [[-1.1934849 ]
#  [-0.09070454]]
# Bias2  [-0.61377513]
# cost  0.5241994
# Epoch  4000
# Hypothesis  [[0.19039729]
#  [0.21214893]
#  [0.27160275]
#  [0.2905538 ]]
# Theta1  [[-1.232664   -0.9129829 ]
#  [-0.40642768  0.62442154]]
# Bias1  [ 0.24915786 -0.03008927]
# Theta2  [[-1.5077816 ]
#  [-0.11315417]]
# Bias2  [-0.54437804]
# cost  0.50063324
# Epoch  5000
# Hypothesis  [[0.16269869]
#  [0.20277414]
#  [0.27385032]
#  [0.3105601 ]]
# Theta1  [[-1.440525   -0.94807583]
#  [-0.6233708   0.5872889 ]]
# Bias1  [ 0.4384573  -0.03709526]
# Theta2  [[-1.8699193 ]
#  [-0.13040613]]
# Bias2  [-0.43758246]
# cost  0.47339138
# Epoch  6000
# Hypothesis  [[0.13369739]
#  [0.19220471]
#  [0.27412608]
#  [0.33563977]]
# Theta1  [[-1.615296  -0.9848768]
#  [-0.8274371  0.5478867]]
# Bias1  [ 0.6924258  -0.04547842]
# Theta2  [[-2.257777 ]
#  [-0.1422563]]
# Bias2  [-0.29432097]
# cost  0.4422658
# Epoch  7000
# Hypothesis  [[0.10636848]
#  [0.18109581]
#  [0.26914912]
#  [0.36626995]]
# Theta1  [[-1.7567217 -1.0211462]
#  [-1.0339781  0.5086611]]
# Bias1  [ 0.99131024 -0.05476705]
# Theta2  [[-2.6584563 ]
#  [-0.14864556]]
# Bias2  [-0.11715955]
# cost  0.40754512
# Epoch  8000
# Hypothesis  [[0.08316013]
#  [0.17063102]
#  [0.25588962]
#  [0.40255976]]
# Theta1  [[-1.8684455 -1.0553645]
#  [-1.2541008  0.4716606]]
# Bias1  [ 1.3164935  -0.06440558]
# Theta2  [[-3.0643992 ]
#  [-0.15097721]]
# Bias2  [0.08947259]
# cost  0.3698476
# Epoch  9000
# Hypothesis  [[0.06497312]
#  [0.16151378]
#  [0.2342036 ]
#  [0.44440556]]
# Theta1  [[-1.9624568  -1.0869809 ]
#  [-1.4885558   0.43810892]]
# Bias1  [ 1.6507709  -0.07390069]
# Theta2  [[-3.4707618 ]
#  [-0.15235099]]
# Bias2  [0.31871367]
# cost  0.33029842
# Elapsed time  5.545923999999999
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

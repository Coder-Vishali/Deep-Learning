# %% [markdown]
# # Deep Neural Network with L2 /L1 Regularization using Keras

# %%
import tensorflow as tf

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
random.seed(42)         # Initialize the random number generator.
np.random.seed(42)      # With the seed reset, the same set of numbers will appear every time. 
#tf.set_random_seed(42)  # sets the graph-level random seed
tf.random.set_seed(42)

# %% [markdown]
# ## Dataset

# %%
# Use the MNIST dataset  of Keras.

mnist = tf.keras.datasets.mnist

(Xtrain, Ytrain) , (Xtest, Ytest) = mnist.load_data()

# size of the datsets

print(Xtrain.shape)
print(Xtest.shape)
print(Ytrain.shape)
print(Ytest.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
# Normalize the data
# 60000 input images are in the train set.
# 10000 input images are in the test set.

Xtrain = Xtrain.reshape((60000, 28*28))    # reshape the input set to size 28*28. 
Xtrain = Xtrain.astype('float32')/255      # normalize to grayscale; set datatype as float32

Xtest = Xtest.reshape((10000, 28*28))      # reshape the input set to size 28*28. 
Xtest = Xtest.astype('float32')/255        # normalize to grayscale; set datatype as float32

Ytrain = tf.keras.utils.to_categorical(Ytrain)
Ytest = tf.keras.utils.to_categorical(Ytest)

# %% [markdown]
# ## DNN Model

# %% [markdown]
# Using Keras, create the DNN or Sequential Model

# %%
# Create a model object

dnnModel = models.Sequential()

# %% [markdown]
# Add dense layers, specifying the number of units in each layer and the activation function used in the layer.

# %%
# Layer 1 = input layer
# specify the input size for in the first layer.

dnnModel.add(layers.Dense(50, activation='relu', input_shape= (28*28,)))

# Layer 2 = hidden layer  with Regularizers
dnnModel.add(layers.Dense(60, activation='relu', kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l2(0.01)) )

# Layer 3 = hidden layer 
dnnModel.add(layers.Dense(30, activation='relu'))

# Layer 4 = output layer
dnnModel.add(layers.Dense(10, activation='softmax'))

dnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                39250
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                3060
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                310
# =================================================================
# Total params: 44,450
# Trainable params: 44,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Regularization and Optimizations of DNN

# %%
# Configure  the model for training, by using appropriate optimizers and regularizations
# Available optimizer: adam, rmsprop, adagrad, sgd
# loss:  objective that the model will try to minimize. 
# Available loss: categorical_crossentropy, binary_crossentropy, mean_squared_error
# metrics: List of metrics to be evaluated by the model during training and testing. 
        
dnnModel.compile( optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'] )

# %% [markdown]
# ## Train the Model

# %%
# train the model

h = dnnModel.fit( Xtrain, Ytrain, epochs=25, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/25
# 750/750 [==============================] - 3s 3ms/step - loss: 0.6819 - accuracy: 0.8837 - val_loss: 0.2926 - val_accuracy: 0.9498
# Epoch 2/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2395 - accuracy: 0.9550 - val_loss: 0.2019 - val_accuracy: 0.9598
# Epoch 3/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1688 - accuracy: 0.9667 - val_loss: 0.1606 - val_accuracy: 0.9663
# Epoch 4/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1376 - accuracy: 0.9723 - val_loss: 0.1505 - val_accuracy: 0.9664
# Epoch 5/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1170 - accuracy: 0.9759 - val_loss: 0.1390 - val_accuracy: 0.9678
# Epoch 6/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1061 - accuracy: 0.9775 - val_loss: 0.1349 - val_accuracy: 0.9676
# Epoch 7/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0938 - accuracy: 0.9805 - val_loss: 0.1350 - val_accuracy: 0.9675
# Epoch 8/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0879 - accuracy: 0.9812 - val_loss: 0.1427 - val_accuracy: 0.9676
# Epoch 9/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9833 - val_loss: 0.1292 - val_accuracy: 0.9707
# Epoch 10/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0782 - accuracy: 0.9833 - val_loss: 0.1338 - val_accuracy: 0.9689
# Epoch 11/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0712 - accuracy: 0.9862 - val_loss: 0.1277 - val_accuracy: 0.9697
# Epoch 12/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0654 - accuracy: 0.9867 - val_loss: 0.1375 - val_accuracy: 0.9665
# Epoch 13/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0633 - accuracy: 0.9878 - val_loss: 0.1419 - val_accuracy: 0.9660
# Epoch 14/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0623 - accuracy: 0.9876 - val_loss: 0.1390 - val_accuracy: 0.9688
# Epoch 15/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0600 - accuracy: 0.9884 - val_loss: 0.1381 - val_accuracy: 0.9701
# Epoch 16/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0551 - accuracy: 0.9899 - val_loss: 0.1319 - val_accuracy: 0.9695
# Epoch 17/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0534 - accuracy: 0.9900 - val_loss: 0.1383 - val_accuracy: 0.9697
# Epoch 18/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0480 - accuracy: 0.9916 - val_loss: 0.1358 - val_accuracy: 0.9697
# Epoch 19/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0485 - accuracy: 0.9913 - val_loss: 0.1505 - val_accuracy: 0.9672
# Epoch 20/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0498 - accuracy: 0.9908 - val_loss: 0.1453 - val_accuracy: 0.9703
# Epoch 21/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0462 - accuracy: 0.9914 - val_loss: 0.1521 - val_accuracy: 0.9675
# Epoch 22/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0481 - accuracy: 0.9912 - val_loss: 0.1496 - val_accuracy: 0.9672
# Epoch 23/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0419 - accuracy: 0.9928 - val_loss: 0.1727 - val_accuracy: 0.9632
# Epoch 24/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0426 - accuracy: 0.9926 - val_loss: 0.1474 - val_accuracy: 0.9672
# Epoch 25/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0429 - accuracy: 0.9920 - val_loss: 0.1769 - val_accuracy: 0.9653

# %%
print('Final training loss \t', h.history['loss'][-1])
print('Final training accuracy ', h.history['accuracy'][-1])
# Out:
# Final training loss 	 0.0429234616458416
# Final training accuracy  0.9920416474342346

# %%
# plot the training loss

plt.plot(h.history['loss'], label='Train loss')
plt.plot(h.history['val_loss'], label='Val loss') 
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Plot of Training Loss')
plt.legend()
plt.show()

# %%
# plot the training accuracy

plt.plot(h.history['accuracy'], label='Train Acc')
plt.plot(h.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Plot of Training Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing the Model

# %%
# testing the model

testLoss, testAccuracy = dnnModel.evaluate( Xtest, Ytest)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.9652

# %%
print('Testing loss \t', testLoss)
print('Testing accuracy ', testAccuracy)
# Out:
# Testing loss 	 0.17904160916805267
# Testing accuracy  0.9652000069618225

# %% [markdown]
# Modify the code to get a better testing accuracy.
# - Change the number of hidden units
# - Increase the number of hidden layers
# - Use a different optimizer
